# %% [markdown]
# <a href="https://colab.research.google.com/github/nitijain18/IMDB-movie-sentiment-analysis-using-RNN/blob/main/movie_sentiment_analysis_rnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import imdb

vocab_size = 10000
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)
print(len(X_train))
print(len(X_test))
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 25000
# 25000

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_length = 200

X_train = pad_sequences(X_train, maxlen=max_length)
X_test = pad_sequences(X_test, maxlen=max_length)

print(X_train.shape)
print(X_test.shape)
# Out:
# (25000, 200)
# (25000, 200)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential([
    Embedding(input_dim=10000, output_dim=128, input_length=200),
    LSTM(64, dropout=0.3, recurrent_dropout=0.3),
    Dropout(0.2),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True
)

history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 119s 364ms/step - accuracy: 0.7497 - loss: 0.5022 - val_accuracy: 0.8062 - val_loss: 0.4294
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 112s 358ms/step - accuracy: 0.8456 - loss: 0.3674 - val_accuracy: 0.7460 - val_loss: 0.5090
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 147s 373ms/step - accuracy: 0.8677 - loss: 0.3208 - val_accuracy: 0.8300 - val_loss: 0.4006
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 137s 358ms/step - accuracy: 0.8921 - loss: 0.2712 - val_accuracy: 0.8304 - val_loss: 0.3974
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 110s 352ms/step - accuracy: 0.8947 - loss: 0.2639 - val_accuracy: 0.8328 - val_loss: 0.4088
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 143s 355ms/step - accuracy: 0.8927 - loss: 0.2678 - val_accuracy: 0.8198 - val_loss: 0.4328

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print("Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.8324 - loss: 0.3989
# Test Accuracy: 0.8324000239372253
